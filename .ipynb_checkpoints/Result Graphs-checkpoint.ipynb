# %%
import matplotlib.pyplot as plt
fig_width = 12
fig_height = 10
import seaborn as sns
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # 1. Variable packet sizes
# - fixed number of nodes
# - fixed distance and topology
# - topology: <img src="broadcast/simulations/1.png">

# %%
algorithms = ["broadcast", "ccbr"]
packet_sizes = [2,10,20]
sent = {}
received = {}
packets = 100
nodes = 8
distance = 2

for algorithm in algorithms:
    print("\n\t", algorithm)
    sent[algorithm] = list()
    received[algorithm] = list()
    
    for packet_size in packet_sizes:
        filename = "results/packet_size/" + algorithm + "_" + str(packet_size) + "_" + str(distance) + "_"  + str(nodes) + ".txt"
        file = open(filename, "r")
        
        received_by_nodes = list()
        sent_by_nodes = list()
        sent_by_sink = list()
        received_by = []

        for i in range(0, nodes+1):
            received_by.append(list())
        for line in file:
            if ('SinkC: Broadcasting packet 101' in line):
                break
            if ('SinkC: Packet sent' in line):
                sent_by_sink.append(line)
            if ('NodeC: Packet sent' in line):
                sent_by_nodes.append(line)
            if ('NodeC: Received the new packet' in line):
                received_by_nodes.append(line)

        print("Packet size: %d" % packet_size)
        print("\tPackets sent by sink: %d" % len(sent_by_sink))
        print("\tPackets sent by nodes: %d" % len(sent_by_nodes))
        print("\tReceived packets: %d" % len(received_by_nodes))
        print("\tReceived packets total: %d/%d, %.2f%%\n" % (len(received_by_nodes), (packets*nodes), (len(received_by_nodes)/(packets*nodes))*100))
        
        sent[algorithm].append(len(sent_by_sink) + len(sent_by_nodes))
        received[algorithm].append(len(received_by_nodes)/(packets*nodes)*100)

print("\n------------ Δ sent Broadcast VS CCBR ------------")        
for i in range(0, len(sent["broadcast"])):
    print("Δ sent %d: %d" % (packet_sizes[i], sent["broadcast"][i] - sent["ccbr"][i]))

x1 = packet_sizes
y1 = sent["broadcast"]  

x2 = packet_sizes
y2 = sent["ccbr"]

plt.figure(figsize=(fig_width, fig_height), dpi= 80)
plt.bar(x1, y1, color = 'c', align = 'center', label="Broadcast") 
plt.bar(x2, y2, color = 'k', align = 'center', label="CCBR") 
plt.title('Sent') 
plt.ylabel('# Sent Packets') 
plt.xlabel('Packet size [bytes]')
plt.legend(loc='upper left')
plt.show()


print("\n------------ Δ received Broadcast VS CCBR ------------")        
for i in range(0, len(received["broadcast"])):
    print("Δ received %d: %.2f" % (packet_sizes[i], received["broadcast"][i] - received["ccbr"][i]))

x1 = packet_sizes
y1 = received["broadcast"]  

x2 = packet_sizes
y2 = received["ccbr"]

plt.figure(figsize=(fig_width, fig_height), dpi= 80)
plt.bar(x1, y1, color = 'c', align = 'center', label="Broadcast") 
plt.bar(x2, y2, color = 'k', align = 'center', label="CCBR") 
plt.title('Received') 
plt.ylabel('# Received Packets') 
plt.xlabel('Packet size [bytes]')
plt.legend(loc='upper left')
plt.show()
# Out:
# 	 broadcast
# Packet size: 2
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 680
# 	Received packets: 680
# 	Received packets total: 680/800, 85.00%
#
# Packet size: 10
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 691
# 	Received packets: 691
# 	Received packets total: 691/800, 86.38%
#
# Packet size: 20
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 678
# 	Received packets: 678
# 	Received packets total: 678/800, 84.75%
#
#
# 	 ccbr
# Packet size: 2
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 533
# 	Received packets: 533
# 	Received packets total: 533/800, 66.62%
#
# Packet size: 10
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 533
# 	Received packets: 533
# 	Received packets total: 533/800, 66.62%
#
# Packet size: 20
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 533
# 	Received packets: 533
# 	Received packets total: 533/800, 66.62%
#
#
# ------------ Δ sent Broadcast VS CCBR ------------
# Δ sent 2: 147
# Δ sent 10: 158
# Δ sent 20: 145
# ------------ Δ received Broadcast VS CCBR ------------
# Δ received 2: 18.38
# Δ received 10: 19.75
# Δ received 20: 18.12

# %% [markdown]
# # 2. Variable number of nodes
# - fixed packet size
# - fixed distance
# - topologies:
#
# <table>
#     <tr>
#         <td><img src="broadcast/simulations/1.png"></td>
#         <td><img src="broadcast/simulations/2.png"></td>
#     </tr>
#     <tr>
#         <td style="text-align:left">
#             <h1>1</h1>
#             <ul>
#                 <li>8 nodes + 1 sink</li>
#                 <li>distance = 2</li>
#                 <li>TX ration = 80%</li>
#                 <li>RX ration = 80%</li>
#             </ul>
#         </td>
#         <td style="text-align:left">
#             <h1>2</h1>
#             <ul>
#                 <li>12 nodes + 1 sink</li>
#                 <li>distance = 2</li>
#                 <li>TX ration = 80%</li>
#                 <li>RX ration = 80%</li>
#             </ul>
#         </td>
#     </tr>
# </table>

# %%
algorithms = ["broadcast", "ccbr"]
packet_size = 2
sent = {}
received = {}
packets = 100
nodes_number = [8,12]
distance = 2

for algorithm in algorithms:
    print("\n\t", algorithm)
    sent[algorithm] = list()
    received[algorithm] = list()
    
    for nodes in nodes_number:
        filename = "results/nodes/" + algorithm + "_" + str(packet_size) + "_" + str(distance) + "_"  + str(nodes) + ".txt"
        file = open(filename, "r")
        
        received_by_nodes = list()
        sent_by_nodes = list()
        sent_by_sink = list()
        received_by = []

        for i in range(0, nodes+1):
            received_by.append(list())
        for line in file:
            if ('SinkC: Broadcasting packet 101' in line):
                break
            if ('SinkC: Packet sent' in line):
                sent_by_sink.append(line)
            if ('NodeC: Packet sent' in line):
                sent_by_nodes.append(line)
            if ('NodeC: Received the new packet' in line):
                received_by_nodes.append(line)

        print("Packet size: %d" % packet_size)
        print("\tPackets sent by sink: %d" % len(sent_by_sink))
        print("\tPackets sent by nodes: %d" % len(sent_by_nodes))
        print("\tReceived packets: %d" % len(received_by_nodes))
        print("\tReceived packets total: %d/%d, %.2f%%\n" % (len(received_by_nodes), (packets*nodes), (len(received_by_nodes)/(packets*nodes))*100))
        
        sent[algorithm].append(len(sent_by_sink) + len(sent_by_nodes))
        received[algorithm].append(len(received_by_nodes)/(packets*nodes)*100)

print("\n------------ Δ sent Broadcast VS CCBR ------------")        
for i in range(0, len(sent["broadcast"])):
    print("Δ sent %d: %d" % (nodes_number[i], sent["broadcast"][i] - sent["ccbr"][i]))

x1 = nodes_number
y1 = sent["broadcast"]  

x2 = nodes_number
y2 = sent["ccbr"]

plt.figure(figsize=(fig_width, fig_height), dpi= 80)
plt.bar(x1, y1, color = 'c', align = 'center', label="Broadcast") 
plt.bar(x2, y2, color = 'k', align = 'center', label="CCBR") 
plt.title('Sent') 
plt.ylabel('# Sent Packets') 
plt.xlabel('# Nodes')
plt.legend(loc='upper left')
plt.show()


print("\n------------ Δ received Broadcast VS CCBR ------------")        
for i in range(0, len(received["broadcast"])):
    print("Δ received %d: %.2f" % (nodes_number[i], received["broadcast"][i] - received["ccbr"][i]))

x1 = nodes_number
y1 = received["broadcast"]  

x2 = nodes_number
y2 = received["ccbr"]

plt.figure(figsize=(fig_width, fig_height), dpi= 80)
plt.bar(x1, y1, color = 'c', align = 'center', label="Broadcast") 
plt.bar(x2, y2, color = 'k', align = 'center', label="CCBR") 
plt.title('Received') 
plt.ylabel('# Received Packets') 
plt.xlabel('# Nodes')
plt.legend(loc='upper left')
plt.show()
# Out:
# 	 broadcast
# Packet size: 2
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 680
# 	Received packets: 680
# 	Received packets total: 680/800, 85.00%
#
# Packet size: 2
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 1170
# 	Received packets: 1170
# 	Received packets total: 1170/1200, 97.50%
#
#
# 	 ccbr
# Packet size: 2
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 533
# 	Received packets: 533
# 	Received packets total: 533/800, 66.62%
#
# Packet size: 2
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 893
# 	Received packets: 893
# 	Received packets total: 893/1200, 74.42%
#
#
# ------------ Δ sent Broadcast VS CCBR ------------
# Δ sent 8: 147
# Δ sent 12: 277
# ------------ Δ received Broadcast VS CCBR ------------
# Δ received 8: 18.38
# Δ received 12: 23.08

# %% [markdown]
# # 3. Variable distance
# - fixed packet size
# - fixed number of nodes
# - topologies:
#
# <table>
#     <tr>
#         <td><img src="broadcast/simulations/5.png"></td>
#         <td><img src="broadcast/simulations/2.png"></td>
#         <td><img src="broadcast/simulations/4.png"></td>
#     </tr>
#     <tr>
#         <td style="text-align:left">
#             <h1>1</h1>
#             <ul>
#                 <li>12 nodes + 1 sink</li>
#                 <li>distance = 1</li>
#                 <li>TX ration = 80%</li>
#                 <li>RX ration = 80%</li>
#             </ul>
#         </td>
#         <td style="text-align:left">
#             <h1>2</h1>
#             <ul>
#                 <li>12 nodes + 1 sink</li>
#                 <li>distance = 2</li>
#                 <li>TX ration = 80%</li>
#                 <li>RX ration = 80%</li>
#             </ul>
#         </td>
#         <td style="text-align:left">
#             <h1>3</h1>
#             <ul>
#                 <li>12 nodes + 1 sink</li>
#                 <li>distance = 3</li>
#                 <li>TX ration = 80%</li>
#                 <li>RX ration = 80%</li>
#             </ul>
#         </td>
#     </tr>
# </table>

# %%
algorithms = ["broadcast", "ccbr"]
packet_size = 2
sent = {}
received = {}
packets = 100
nodes = 12
distances = [1,2,3]

for algorithm in algorithms:
    print("\n\t", algorithm)
    sent[algorithm] = list()
    received[algorithm] = list()
    
    for distance in distances:
        filename = "results/distances/" + algorithm + "_" + str(packet_size) + "_" + str(distance) + "_"  + str(nodes) + ".txt"
        file = open(filename, "r")
        
        received_by_nodes = list()
        sent_by_nodes = list()
        sent_by_sink = list()
        received_by = []

        for i in range(0, nodes+1):
            received_by.append(list())
        for line in file:
            if ('SinkC: Broadcasting packet 101' in line):
                break
            if ('SinkC: Packet sent' in line):
                sent_by_sink.append(line)
            if ('NodeC: Packet sent' in line):
                sent_by_nodes.append(line)
            if ('NodeC: Received the new packet' in line):
                received_by_nodes.append(line)

        print("Packet size: %d" % packet_size)
        print("\tPackets sent by sink: %d" % len(sent_by_sink))
        print("\tPackets sent by nodes: %d" % len(sent_by_nodes))
        print("\tReceived packets: %d" % len(received_by_nodes))
        print("\tReceived packets total: %d/%d, %.2f%%\n" % (len(received_by_nodes), (packets*nodes), (len(received_by_nodes)/(packets*nodes))*100))
        
        sent[algorithm].append(len(sent_by_sink) + len(sent_by_nodes))
        received[algorithm].append(len(received_by_nodes)/(packets*nodes)*100)

print("\n------------ Δ sent Broadcast VS CCBR ------------")        
for i in range(0, len(sent["broadcast"])):
    print("Δ sent %d: %d" % (distances[i], sent["broadcast"][i] - sent["ccbr"][i]))

x1 = distances
y1 = sent["broadcast"]  

x2 = distances
y2 = sent["ccbr"]

plt.figure(figsize=(fig_width, fig_height), dpi= 80)
plt.bar(x1, y1, color = 'c', align = 'center', label="Broadcast") 
plt.bar(x2, y2, color = 'k', align = 'center', label="CCBR") 
plt.title('Sent') 
plt.ylabel('# Sent Packets') 
plt.xlabel('Distance')
plt.legend(loc='upper left')
plt.show()


print("\n------------ Δ received Broadcast VS CCBR ------------")        
for i in range(0, len(received["broadcast"])):
    print("Δ received %d: %.2f" % (distances[i], received["broadcast"][i] - received["ccbr"][i]))

x1 = distances
y1 = received["broadcast"]  

x2 = distances
y2 = received["ccbr"]

plt.figure(figsize=(fig_width, fig_height), dpi= 80)
plt.bar(x1, y1, color = 'c', align = 'center', label="Broadcast") 
plt.bar(x2, y2, color = 'k', align = 'center', label="CCBR") 
plt.title('Received') 
plt.ylabel('# Received Packets') 
plt.xlabel('Distance')
plt.legend(loc='upper left')
plt.show()
# Out:
# 	 broadcast
# Packet size: 2
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 1194
# 	Received packets: 1194
# 	Received packets total: 1194/1200, 99.50%
#
# Packet size: 2
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 1170
# 	Received packets: 1170
# 	Received packets total: 1170/1200, 97.50%
#
# Packet size: 2
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 1022
# 	Received packets: 1022
# 	Received packets total: 1022/1200, 85.17%
#
#
# 	 ccbr
# Packet size: 2
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 936
# 	Received packets: 936
# 	Received packets total: 936/1200, 78.00%
#
# Packet size: 2
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 893
# 	Received packets: 893
# 	Received packets total: 893/1200, 74.42%
#
# Packet size: 2
# 	Packets sent by sink: 100
# 	Packets sent by nodes: 821
# 	Received packets: 821
# 	Received packets total: 821/1200, 68.42%
#
#
# ------------ Δ sent Broadcast VS CCBR ------------
# Δ sent 1: 258
# Δ sent 2: 277
# Δ sent 3: 201
# ------------ Δ received Broadcast VS CCBR ------------
# Δ received 1: 21.50
# Δ received 2: 23.08
# Δ received 3: 16.75
